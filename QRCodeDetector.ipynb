# %%
# %matplotlib inline

# Import modules
import cv2
import matplotlib.pyplot as plt
from dataPath import DATA_PATH
import numpy as np

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (10.0, 10.0)
#matplotlib.rcParams['image.cmap'] = 'gray'

# %%
# Image Path
imgPath = "IDCard-Satya.png"

img=cv2.imread(imgPath)

# %%
plt.imshow(img[:,:,::-1])

# %%
qrDecoder = cv2.QRCodeDetector()

# %%
opencvData, bbox, rectifiedImage = qrDecoder.detectAndDecode(img)

# %%
if opencvData != None:
    print("QR Code Detected")
else:
    print("QR Code NOT Detected")
# Out:
# QR Code Detected

# %%
bbox=np.uint8(bbox)

# %%
bbox = list(map(tuple, np.squeeze(bbox)))

# %%
n = len(bbox)

for i in range(0,n):
    cv2.line(img, bbox[i], bbox[(i+1) % n], (255,0,0), 2)

# %%
print("QR Code Detected!")
# Out:
# QR Code Detected!

# %%
print(opencvData)
# Out:
# Name: Satya, ID: 1234

# %%
resultImagePath = "QRCode-Output.png"
cv2.imshow('QRCode', img)
cv2.imwrite(resultImagePath, img)
cv2.waitKey(0)
cv2.destroyAllWindows()
